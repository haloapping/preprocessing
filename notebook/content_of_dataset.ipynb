# %% [markdown]
# # Content
#
# ##### Price Tomato
# Tomato Price across markets in karnataka from 2016-2018
#
# ##### Features
# - Market: name of the market where vegetable sold
# - Arrival Date: date Vegetable arrived
# - Arrivals (Tonnes): number of tonnes arrives
# - Variety: variety of the tomato
# - Minimum Price(Rs./Quintal): minimum Price Per Quintal(100 kgs)
# - Maximum Price(Rs./Quintal): maximum Price Per Quintal(100kgs)
# - Modal Price(Rs./Quintal): Average Price

# %% [markdown]
# # What to predict?

# %% [markdown]
# ?

# %% [markdown]
# # Import Modules

# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %% [markdown]
# # Initialize and load dataset

# %%
raw_df = pd.read_csv('../dataset/tomato/Price of Tomato Karnataka(2016-2018).csv')

# %%
raw_df.describe(include='all')
# Out:
#        Market Arrival Date  Arrivals (Tonnes) Variety  \
# count   11456        11321       11321.000000   11421
# unique     40          844                NaN       2
# top     Kolar   16/08/2016                NaN  Tomato
# freq      954           24                NaN   11196
# mean      NaN          NaN          80.269146     NaN
# std       NaN          NaN         154.967086     NaN
# min       NaN          NaN           1.000000     NaN
# 25%       NaN          NaN           4.000000     NaN
# 50%       NaN          NaN          19.000000     NaN
# 75%       NaN          NaN          70.000000     NaN
# max       NaN          NaN        1931.000000     NaN
#
#        Minimum Price(Rs./Quintal) Maximum Price(Rs./Quintal)  \
# count                       11456                      11456
# unique                        679                        934
# top                           300                       1000
# freq                         1179                        939
# ...

# %% [markdown]
# # Show dataset in table

# %%
raw_df.head(10)
# Out:
#       Market Arrival Date  Arrivals (Tonnes) Variety  \
# 0  Bagepalli     2/1/2016                6.0  Tomato
# 1  Bagepalli     4/1/2016                6.0  Tomato
# 2  Bagepalli     5/1/2016                6.0  Tomato
# 3  Bagepalli     6/1/2016                4.0  Tomato
# 4  Bagepalli     7/1/2016                5.0  Tomato
# 5  Bagepalli    11/1/2016                5.0  Tomato
# 6  Bagepalli    12/1/2016                6.0  Tomato
# 7  Bagepalli   13/01/2016                7.0  Tomato
# 8  Bagepalli   14/01/2016                7.0  Tomato
# 9  Bagepalli   16/01/2016                5.0  Tomato
#
#   Minimum Price(Rs./Quintal) Maximum Price(Rs./Quintal)  \
# 0                       1000                       1800
# 1                        900                       1800
# 2                       1400                       2500
# 3                       1400                       3000
# 4                       1400                       2600
# ...

# %% [markdown]
# # Number of row and column

# %%
print('Number of row    :', raw_df.shape[0])
print('NUmber of column :', raw_df.shape[1])
# Out:
# Number of row    : 11456
# NUmber of column : 7

# %% [markdown]
# # Feature Category
#
# #### Qualitative
# - <b>Nominal</b>: Market, Variety
# - <b>Ordinal</b>: Arrival Date
#
# #### Quantitative
# - <b>Ratio</b>: Arrivals (Tonnes), Minimum Price(Rs./Quintal), Maximum Price(Rs./Quintal), and Modal Price(Rs./Quintal)

# %% [markdown]
# # Feature datatype
# Fitur Minimum Price(Rs./Quintal), Maximum Price(Rs./Quintal), dan Modal Price(Rs./Quintal) memiliki datatype yang salah yaitu object. Pada tampilan table terlihat bahwa data direpresentasikan dalam bentuk quantitative. Hal ini terjadi, karena beberapa baris pada dataset pengisiannya mismatched berupa string.

# %%
raw_df.dtypes.to_frame().rename(columns={0:'Datatype'})
# Out:
#                            Datatype
# Market                       object
# Arrival Date                 object
# Arrivals (Tonnes)           float64
# Variety                      object
# Minimum Price(Rs./Quintal)   object
# Maximum Price(Rs./Quintal)   object
# Modal Price(Rs./Quintal)     object

# %% [markdown]
# # Mismatced Value
# Sebanyak 35 data pada kolom Minimum Price(Rs./Quintal) dan Maximum Price(Rs./Quintal) mismatch value. Data yang dimasukkan berupa 'NR' yang seharusnya data quantitative.

# %%
raw_df[(raw_df['Minimum Price(Rs./Quintal)'] == 'NR') | (raw_df['Maximum Price(Rs./Quintal)'] == 'NR')].head(10)
# Out:
#          Market Arrival Date  Arrivals (Tonnes) Variety  \
# 9037  Bagepalli   21/11/2017               13.0     NaN
# 9038  Bagepalli   22/11/2017               13.0     NaN
# 9039  Bagepalli   23/11/2017               14.0     NaN
# 9040  Bagepalli   25/11/2017               16.0     NaN
# 9041  Bagepalli   27/11/2017               16.0     NaN
# 9042  Bagepalli   28/11/2017               16.0     NaN
# 9043  Bagepalli   29/11/2017               16.0     NaN
# 9044  Bagepalli   30/11/2017               18.0     NaN
# 9422  Bagepalli    2/12/2017               20.0     NaN
# 9423  Bagepalli    4/12/2017               21.0     NaN
#
#      Minimum Price(Rs./Quintal) Maximum Price(Rs./Quintal)  \
# 9037                         NR                         NR
# 9038                         NR                         NR
# 9039                         NR                         NR
# 9040                         NR                         NR
# ...

# %% [markdown]
# # Duplicate Value
# Terdapat 76 baris data yang duplikat yang semua berada pada market Kolar.

# %%
raw_df[raw_df.duplicated()].head(10)
# Out:
#       Market Arrival Date  Arrivals (Tonnes) Variety  \
# 9689   Kolar          NaN                NaN  Tomato
# 9697   Kolar          NaN                NaN  Tomato
# 9701   Kolar          NaN                NaN  Tomato
# 9703   Kolar          NaN                NaN  Tomato
# 9705   Kolar          NaN                NaN  Tomato
# 9707   Kolar          NaN                NaN  Tomato
# 9709   Kolar          NaN                NaN  Tomato
# 10113  Kolar          NaN                NaN  Tomato
# 10117  Kolar          NaN                NaN  Tomato
# 10121  Kolar          NaN                NaN  Tomato
#
#       Minimum Price(Rs./Quintal) Maximum Price(Rs./Quintal)  \
# 9689                         334                       1000
# 9697                         334                        667
# 9701                         334                        734
# 9703                         334                        667
# 9705                         334                        667
# ...

# %% [markdown]
# # Missing Value
# Missing value direpresentasikan dalam bentuk persen. Kolom yang memiliki missing value, antara lain Arrival Date sebesar 0.0118%, Arrivals (Tonnes) sebesar 0.0118%, dan Variety sebesar 0.0031%.

# %%
round(raw_df.isna().sum().to_frame().rename(columns={0:'Missing Value'}) / 11456, 4)
# Out:
#                             Missing Value
# Market                             0.0000
# Arrival Date                       0.0118
# Arrivals (Tonnes)                  0.0118
# Variety                            0.0031
# Minimum Price(Rs./Quintal)         0.0000
# Maximum Price(Rs./Quintal)         0.0000
# Modal Price(Rs./Quintal)           0.0000

# %%
raw_df[raw_df['Arrival Date'].isna() | raw_df['Arrivals (Tonnes)'].isna() | raw_df['Variety'].isna()]
# Out:
#                     Market Arrival Date  Arrivals (Tonnes) Variety  \
# 166                Hoskote          NaN                NaN  Tomato
# 9037             Bagepalli   21/11/2017               13.0     NaN
# 9038             Bagepalli   22/11/2017               13.0     NaN
# 9039             Bagepalli   23/11/2017               14.0     NaN
# 9040             Bagepalli   25/11/2017               16.0     NaN
# 9041             Bagepalli   27/11/2017               16.0     NaN
# 9042             Bagepalli   28/11/2017               16.0     NaN
# 9043             Bagepalli   29/11/2017               16.0     NaN
# 9044             Bagepalli   30/11/2017               18.0     NaN
# 9422             Bagepalli    2/12/2017               20.0     NaN
# 9423             Bagepalli    4/12/2017               21.0     NaN
# 9424             Bagepalli    5/12/2017               22.0     NaN
# 9425             Bagepalli    6/12/2017               23.0     NaN
# ...
